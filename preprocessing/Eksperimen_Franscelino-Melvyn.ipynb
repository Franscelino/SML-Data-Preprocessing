# %% [markdown]
# # Eksperimen Dataset: SP 500 Analyst Rating

# %% [markdown]
# ## 1. Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## 2. Load Dataset

# %%
df = pd.read_csv('../namadataset_raw/sp_500_analyst_rating_and_price_target_accuracy.csv')
df.head()

# %% [markdown]
# ## 3. Data Exploration & Cleaning

# %%
df.info()

# %%
# Memilih fitur yang relevan
features = ['from_grade', 'to_grade', 'action', 'implied_direction']
target = 'accuracy_30d'

df = df.dropna(subset=[target] + features)

# %% [markdown]
# ## 4. Preprocessing

# %%
le = LabelEncoder()
for col in ['from_grade', 'to_grade', 'action']:
    df[col] = le.fit_transform(df[col].astype(str))

# %%
df.head()

# %% [markdown]
# ## 5. Save Preprocessed Data

# %%
import os
os.makedirs('namadataset_preprocessing', exist_ok=True)
df.to_csv('namadataset_preprocessing/sp_500_analyst_rating_and_price_target_accuracy.csv', index=False)
print('Data preprocessed saved!')
